# %%
from simulation_parser import parse_simulation_files
from output_generator import get_velocities

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
static_file = "./static-N5-ordered.txt"
dynamic_file = "./dynamic-N5-ordered.txt"

# %%
sim_info = parse_simulation_files(static_file, dynamic_file)

# %%
velocities = get_velocities(sim_info)

# %%
print(velocities[0])
print(velocities[0].mean())
# Out:
# [ 9.83123547  9.92615837 10.99664686 11.04967042 11.18269104]
# 10.59728042939645

# %%
print(velocities[-100]) 
print(velocities[-100].mean())
# Out:
# [10.597298   10.59730462 10.59717703 10.5971318  10.59749069]
# 10.597280429397

# %%
velocities[750]
# Out:
# array([10.1589053 , 10.46901449, 10.99664686, 10.45671203, 10.90512347])

# %%
velocities[768]
# Out:
# array([10.42933519, 10.87758533, 10.99664686, 10.49790432, 10.18493045])

# %%
sns.set_style("darkgrid")
for i in range(velocities.shape[1]):
    plt.plot(sim_info.instants, velocities[:, i])
plt.ylabel("Velocidad ($\\frac{cm}{s}$)")
plt.xlabel("Tiempo (s)")
# Out:
# Text(0.5, 0, 'Tiempo (s)')

# %%
sns.set_style("darkgrid")
for i in range(velocities.shape[1]):
    plt.plot(sim_info.instants[:1001], velocities[:1001, i])
plt.ylabel("Velocidad ($\\frac{cm}{s}$)")
plt.xlabel("Tiempo (s)")
# Out:
# Text(0.5, 0, 'Tiempo (s)')

# %%
accum_vs = velocities.sum(axis=1)
for i in range(accum_vs.size):
    print(accum_vs[i] / velocities[i].size)
# Out:
# 10.59728042939645
# 10.59728042939645
# 10.59728042939645
# 10.59728042939645
# 10.59728042939645
# 10.59728042939645
# 10.59728042939645
# 10.59728042939645
# 10.59728042939645
# 10.59728042939645
# 10.59728042939645
# 10.59728042939645
# 10.59728042939645
# 10.59728042939645
# 10.59728042939645
# 10.59728042939645
# 10.59728042939645
# 10.59728042939645
# 10.59728042939645
# 10.59728042939645
# 10.59728042939645
# 10.59728042939645
# 10.59728042939645
# 10.59728042939645
# 10.59728042939645
# 10.59728042939645
# 10.59728042939645
# 10.59728042939645
# 10.59728042939645
# 10.59728042939645
# 10.59728042939645
# 10.59728042939645
# 10.59728042939645
# 10.59728042939645
# 10.59728042939645
# 10.59728042939645
# 10.59728042939645
# 10.59728042939645
# 10.59728042939645
# 10.59728042939645
# 10.59728042939645
# 10.59728042939645
# 10.59728042939645
# 10.59728042939645
# 10.59728042939645
# 10.59728042939645
# 10.59728042939645
# 10.59728042939645
# 10.59728042939645
# 10.59728042939645
# ...

# %%
for i in range(velocities.shape[0]):
    print(velocities[i].std())
# Out:
# 0.5906074039684892
# 0.5906074039684892
# 0.5906074039684892
# 0.5906074039684892
# 0.5906074039684892
# 0.5906074039684892
# 0.5906074039684892
# 0.5906074039684892
# 0.5906074039684892
# 0.5906074039684892
# 0.5906074039684892
# 0.5906074039684892
# 0.5906074039684892
# 0.5906074039684892
# 0.5906074039684892
# 0.5906074039684892
# 0.5906074039684892
# 0.5906074039684892
# 0.5906074039684892
# 0.5906074039684892
# 0.5906074039684892
# 0.5906074039684892
# 0.5906074039684892
# 0.5906074039684892
# 0.5906074039684892
# 0.5906074039684892
# 0.5906074039684892
# 0.5906074039684892
# 0.5906074039684892
# 0.5906074039684892
# 0.5906074039684892
# 0.5906074039684892
# 0.5906074039684892
# 0.5906074039684892
# 0.5906074039684892
# 0.5906074039684892
# 0.5906074039684892
# 0.5906074039684892
# 0.5906074039684892
# 0.5906074039684892
# 0.5906074039684892
# 0.5906074039684892
# 0.5906074039684892
# 0.5906074039684892
# 0.5906074039684892
# 0.5906074039684892
# 0.5906074039684892
# ...

# %%
import numpy as np
x = sim_info.instants
y = velocities.std(axis=1)

# %%
sns.set_style("darkgrid")
plt.plot(x, y)
plt.xlabel("Tiempo (s)")
plt.ylabel("Desvío estándar de la velocidad promedio ($\\frac{cm}{s}$)")
# Out:
# Text(0, 0.5, 'Desvío estándar de la velocidad promedio ($\\frac{cm}{s}$)')

# %%
velocities.size
# Out:
# 30005

# %%
sim_info.instants[-50]
# Out:
# 595.1

# %%
from pdf import data_to_pdf
pdf, values, class_width = data_to_pdf(velocities[5000:], (10.590, 10.605))

# %%
from plot_generator import plot_pdf

# %%
plot_pdf(values, pdf)
