# %%
from utils.argument_parser  import parse_order_over_iterations_arguments
from utils.ref_files_parser import read_order_over_iterations_files
from utils.plot_generator   import plot_polarization_over_iterations_from_files
# Out:
# usage: ipykernel_launcher.py [-h] -s STATIC_FILES -d DYNAMIC_FILES -p
#                              POLARIZATION_FILES -c COLORS_FILE -o
#                              OUT_IMAGE_FILE
# ipykernel_launcher.py: error: the following arguments are required: -s/--static-files, -d/--dynamic-files, -p/--polarization-files, -c/--colors-file, -o/--out-image-file
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# d:\Programs\Python\Python310\lib\site-packages\IPython\core\interactiveshell.py:3405: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
#static_files,     dynamic_files,     polarization_files,     colors_file, out_image_file = parse_order_over_iterations_arguments()

static_file_list, dynamic_file_list, polarization_file_list, colors      = read_order_over_iterations_files("sample/static_files.txt", "sample/dynamic_files.txt", "sample/polarization_files.txt", "sample/colors_file.txt")

plot_polarization_over_iterations_from_files(static_file_list, dynamic_file_list, polarization_file_list, "order_over_iterations.png", colors)
